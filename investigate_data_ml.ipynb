# %% [markdown]
# <a href="https://colab.research.google.com/github/sculd/sandbox_gym/blob/master/investigate_data_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_ml.csv')

# %%
df[df.return_jump_30m == True]
# Out:
#         epochSeconds   market    symbol  stepChange  priceAtAnalysis  minDrop  \
# 150736    1663333380  binance  COTIUSDT     -0.0022           0.0924    -0.01
# 151091    1663333440  binance  COTIUSDT      0.0076           0.0931    -0.01
# 151446    1663333500  binance  COTIUSDT     -0.0011           0.0930    -0.01
# 152511    1663333680  binance  COTIUSDT     -0.0021           0.0940    -0.01
# 152866    1663333740  binance  COTIUSDT      0.0021           0.0942    -0.01
# ...              ...      ...       ...         ...              ...      ...
# 946947    1663467960  binance   UFTBUSD      0.0021           0.3748    -0.03
# 947302    1663468020  binance   UFTBUSD     -0.0024           0.3739    -0.03
# 947657    1663468080  binance   UFTBUSD      0.0008           0.3742    -0.03
# 948012    1663468140  binance   UFTBUSD      0.0024           0.3751    -0.03
# 948722    1663468260  binance   UFTBUSD     -0.0042           0.3777    -0.03
#
# ...

# %%
df[df.return_jump_30m == True]['minDrop'].hist(bins=20)

# %%
df[df.return_jump_30m == True]['maxJump'].hist(bins=20)

# %%
df.corr()
# Out:
#                      epochSeconds  stepChange  priceAtAnalysis   minDrop  \
# epochSeconds             1.000000    0.002334         0.000944  0.101195
# stepChange               0.002334    1.000000        -0.000138  0.034637
# priceAtAnalysis          0.000944   -0.000138         1.000000  0.032449
# minDrop                  0.101195    0.034637         0.032449  1.000000
# maxJump                 -0.063282    0.020421        -0.027409 -0.586273
# changeSinceMinDrop      -0.079945    0.256970        -0.020690 -0.288744
# changeSinceMaxJump       0.042206    0.171264         0.019221  0.744365
# normalizedPricePT3H      0.082808    0.138455        -0.002560  0.199595
# changePT6H               0.117666    0.056983        -0.000367 -0.203861
# rsiPT3H                 -0.014534    0.029361        -0.026954 -0.016512
# bandwidthPT2H2          -0.060943   -0.007227        -0.031489 -0.696281
# bandPercentPT2H2         0.060943    0.161168        -0.003430  0.225618
# ...

# %%
sns.set(rc = {'figure.figsize':(15, 12)})
sns.heatmap(df.corr(), annot=True)
